# %% [markdown]
# # Practice 3：Docker 中的 Jupyter
# 先執行下面程式，確認輸出 Hello Docker from Jupyter!。
# 瀏覽器使用電腦的 8888 連接埠；Docker 把流量轉到容器的 8888。

# %%
print("Hello Docker from Jupyter!")
# Out:
# Hello Docker from Jupyter!

# %% [markdown]
# docker start homework-notebook
# docker logs homework-notebook
# http://localhost:8888
